# %%
import sys
sys.path.insert(0, '..')

from src.task_optimization import collect_all_equations, evaluate_model, plot_tradeoff_curve, plot_predicted_vs_true_loss, display_all_equations
from src.pysr_optimization import load_curves

curves = load_curves('runs_data.json', total=4300, n=2)
models_df = collect_all_equations()

tradeoff_df, simulation_df, best_complexity_df = evaluate_model(
    curves=curves,
    models_df=models_df,
    total=4300,
    epsilons=(0.02, 0.015, 0.01, 0.008, 0.006, 0.004, 0.002, 0.001)
)
# Out:
# Detected IPython. Loading juliacall extension. See https://juliapy.github.io/PythonCall.jl/stable/compat/#IPython
# Attempting to load model from /Users/danielgieseler/Documents/Code/early_stop/src/../outputs/20251202_173321_IhlsSJ/checkpoint.pkl...
# Attempting to load model from /Users/danielgieseler/Documents/Code/early_stop/src/../outputs/20251202_174431_lyPsPm/checkpoint.pkl...
# Attempting to load model from /Users/danielgieseler/Documents/Code/early_stop/src/../outputs/20251202_180406_8c8jdG/checkpoint.pkl...
# Attempting to load model from /Users/danielgieseler/Documents/Code/early_stop/src/../outputs/20251202_185054_7ZvNIE/checkpoint.pkl...
# Attempting to load model from /Users/danielgieseler/Documents/Code/early_stop/src/../outputs/20251202_185431_IUrVuo/checkpoint.pkl...
# Attempting to load model from /Users/danielgieseler/Documents/Code/early_stop/src/../outputs/20251202_185448_2gDGyw/checkpoint.pkl...
# ...

# %%
tradeoff_df
# Out:
#      complexity  eq_id  epsilon   steps
# 0             9      0    0.020   610.0
# 1             9      0    0.015   937.5
# 2             9      0    0.010  1670.0
# 3             9      0    0.008  1993.0
# 4             9      0    0.006  2321.0
# ..          ...    ...      ...     ...
# 211          14     26    0.008  1067.0
# 212          14     26    0.006  1201.0
# 213          14     26    0.004  4300.0
# 214          14     26    0.002  4300.0
# 215          14     26    0.001  4300.0
#
# [216 rows x 4 columns]

# %%
display_all_equations(best_complexity_df)
# Out:
# ## All Equations
#
# | Label | Steps | Equation |
# |---|---|---|
# | C_9_0 | 2616.0 | $\delta_{steps} \left(0.06354 derivative_{3} - 4.05 \cdot 10^{-6}\right) + last_{loss}$ |
# | C_9_5 | 2636.3 | $0.0573 \delta_{steps} \left(derivative_{3} - 6.99 \cdot 10^{-5}\right) + last_{loss}$ |
# | C_9_9 | 2961.8 | $- 4.95 \cdot 10^{-6} \delta_{steps} + 50.7356671740233 derivative_{3} + last_{loss}$ |
# | C_9_12 | 4300.0 | $0.01437 \delta_{steps} derivative_{3} + last_{loss} - 0.006886104$ |
# | C_9_14 | 2630.2 | $- \delta_{steps} \left(4.3 \cdot 10^{-6} - 0.0523 derivative_{3}\right) + last_{loss}$ |
# | C_9_18 | 2942.2 | $- 4.53 \cdot 10^{-6} \delta_{steps} + 66.711140760507 derivative_{3} + last_{loss}$ |
# | C_9_22 | 3241.8 | $last_{loss} \left(0.2043 \delta_{steps} derivative_{3} + 0.99\right)$ |
# | C_10_23 | 3266.5 | $0.991 last_{loss} e^{0.2255 \delta_{steps} derivative_{3}}$ |
# ...

# %%
plot_tradeoff_curve(tradeoff_df)

# %%
plot_predicted_vs_true_loss(simulation_df, label="C_11_1", n_th = 1, minimum_step = 200)
